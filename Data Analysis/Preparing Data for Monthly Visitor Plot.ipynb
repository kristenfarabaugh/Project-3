# %% [markdown]
# ## Preparing Data for Monthly Visitor Plot

# %%
#Import dependences
import pandas as pd
import numpy as np
import re
import json

# %%
park_info = pd.read_csv('../Resources/Monthly Visitors By Park.csv')
park_info
# Out:
#                                Park   Dec-22   Nov-22   Oct-22   Sep-22  \
# 0    Abraham Lincoln Birthplace NHP    6,784   12,503   21,857   31,130
# 1                         Acadia NP   22,506   70,675  521,646  697,292
# 2                         Adams NHP      361      425    2,207    1,811
# 3          African Burial Ground NM    2,583    3,871    3,173    3,134
# 4              Agate Fossil Beds NM       55      224    1,172    2,501
# ..                              ...      ...      ...      ...      ...
# 382                      Wupatki NM    7,000    9,786   16,522   23,900
# 383                  Yellowstone NP   30,794   17,687  236,567  567,587
# 384                     Yosemite NP  131,100  178,786  381,612  424,374
# 385      Yukon-Charley Rivers NPRES        0        0        0       15
# 386                         Zion NP  176,846  291,044  459,697  423,654
#
#       Aug-22   Jul-22   Jun-22   May-22   Apr-22  Mar-22  Feb-22  Jan-22
# ...
