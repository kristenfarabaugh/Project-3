# %% [markdown]
# ## Preparing Data for Monthly Visitor Plot

# %%
#Import dependences
import pandas as pd
import numpy as np
import re
import json

# %%
park_info = pd.read_csv('../Resources/Monthly Visitors By Park.csv')
park_info
# Out:
#                                Park   Dec-22   Nov-22   Oct-22   Sep-22  \
# 0    Abraham Lincoln Birthplace NHP    6,784   12,503   21,857   31,130
# 1                         Acadia NP   22,506   70,675  521,646  697,292
# 2                         Adams NHP      361      425    2,207    1,811
# 3          African Burial Ground NM    2,583    3,871    3,173    3,134
# 4              Agate Fossil Beds NM       55      224    1,172    2,501
# ..                              ...      ...      ...      ...      ...
# 382                      Wupatki NM    7,000    9,786   16,522   23,900
# 383                  Yellowstone NP   30,794   17,687  236,567  567,587
# 384                     Yosemite NP  131,100  178,786  381,612  424,374
# 385      Yukon-Charley Rivers NPRES        0        0        0       15
# 386                         Zion NP  176,846  291,044  459,697  423,654
#
#       Aug-22   Jul-22   Jun-22   May-22   Apr-22  Mar-22  Feb-22  Jan-22
# ...

# %%
park_info = park_info[["Park",
                     "Jan-22",
                    "Feb-22",
                    "Mar-22",
                    "Apr-22",
                    "May-22",
                     "Jun-22",
                     "Jul-22",
                     "Aug-22",
                     "Sep-22",
                    "Oct-22",
                    "Nov-22",
                    "Dec-22"]]
park_info
# Out:
#                                Park  Jan-22  Feb-22  Mar-22   Apr-22   May-22  \
# 0    Abraham Lincoln Birthplace NHP   5,833  10,174  16,447   25,848   30,360
# 1                         Acadia NP  10,411  13,045  22,476  105,126  327,466
# 2                         Adams NHP      84     125     204      262    1,343
# 3          African Burial Ground NM     458   1,163   1,667    2,625    2,213
# 4              Agate Fossil Beds NM     113     117     400      764    2,123
# ..                              ...     ...     ...     ...      ...      ...
# 382                      Wupatki NM     NaN     NaN     NaN      NaN        9
# 383                  Yellowstone NP     NaN     NaN     NaN      NaN  539,172
# 384                     Yosemite NP     NaN     NaN     NaN      NaN      NaN
# 385      Yukon-Charley Rivers NPRES     NaN     NaN     NaN      NaN      NaN
# 386                         Zion NP     NaN     NaN     NaN      NaN      NaN
#
# ...

# %%
#Convert all monthly visitor columns to numbers
park_info["Jan-22"] = park_info["Jan-22"].str.replace(',', '').apply(pd.to_numeric)
park_info["Feb-22"] = park_info["Feb-22"].str.replace(',', '').apply(pd.to_numeric)
park_info["Mar-22"] = park_info["Mar-22"].str.replace(',', '').apply(pd.to_numeric)
park_info["Apr-22"] = park_info["Apr-22"].str.replace(',', '').apply(pd.to_numeric)
park_info["May-22"] = park_info["May-22"].str.replace(',', '').apply(pd.to_numeric)
park_info["Jun-22"] = park_info["Jun-22"].str.replace(',', '').apply(pd.to_numeric)
park_info["Jul-22"] = park_info["Jul-22"].str.replace(',', '').apply(pd.to_numeric)
park_info["Aug-22"] = park_info["Aug-22"].str.replace(',', '').apply(pd.to_numeric)
park_info["Sep-22"] = park_info["Sep-22"].str.replace(',', '').apply(pd.to_numeric)
park_info["Oct-22"] = park_info["Oct-22"].str.replace(',', '').apply(pd.to_numeric)
park_info["Nov-22"] = park_info["Nov-22"].str.replace(',', '').apply(pd.to_numeric)
park_info["Dec-22"] = park_info["Dec-22"].str.replace(',', '').apply(pd.to_numeric)

park_info
# Out:
#                                Park   Jan-22   Feb-22   Mar-22    Apr-22  \
# 0    Abraham Lincoln Birthplace NHP   5833.0  10174.0  16447.0   25848.0
# 1                         Acadia NP  10411.0  13045.0  22476.0  105126.0
# 2                         Adams NHP     84.0    125.0    204.0     262.0
# 3          African Burial Ground NM    458.0   1163.0   1667.0    2625.0
# 4              Agate Fossil Beds NM    113.0    117.0    400.0     764.0
# ..                              ...      ...      ...      ...       ...
# 382                      Wupatki NM      NaN      NaN      NaN       NaN
# 383                  Yellowstone NP      NaN      NaN      NaN       NaN
# 384                     Yosemite NP      NaN      NaN      NaN       NaN
# 385      Yukon-Charley Rivers NPRES      NaN      NaN      NaN       NaN
# 386                         Zion NP      NaN      NaN      NaN       NaN
#
#        May-22    Jun-22    Jul-22    Aug-22  Sep-22  Oct-22  Nov-22  Dec-22
# ...

# %%
#Change NaNs to 0s

columns = ["Jan-22",
            "Feb-22",
            "Mar-22",
            "Apr-22",
            "May-22",
             "Jun-22",
             "Jul-22",
             "Aug-22",
             "Sep-22",
            "Oct-22",
            "Nov-22",
            "Dec-22"]

for column in columns:
    park_info[column] = park_info[column].fillna(0)

park_info
# Out:
#                                Park   Jan-22   Feb-22   Mar-22    Apr-22  \
# 0    Abraham Lincoln Birthplace NHP   5833.0  10174.0  16447.0   25848.0
# 1                         Acadia NP  10411.0  13045.0  22476.0  105126.0
# 2                         Adams NHP     84.0    125.0    204.0     262.0
# 3          African Burial Ground NM    458.0   1163.0   1667.0    2625.0
# 4              Agate Fossil Beds NM    113.0    117.0    400.0     764.0
# ..                              ...      ...      ...      ...       ...
# 382                      Wupatki NM      0.0      0.0      0.0       0.0
# 383                  Yellowstone NP      0.0      0.0      0.0       0.0
# 384                     Yosemite NP      0.0      0.0      0.0       0.0
# 385      Yukon-Charley Rivers NPRES      0.0      0.0      0.0       0.0
# 386                         Zion NP      0.0      0.0      0.0       0.0
#
#        May-22    Jun-22    Jul-22    Aug-22  Sep-22  Oct-22  Nov-22  Dec-22  \
# ...

# %%
#Get totalVisitors2022 column
park_info["totalVisitors2022"] = park_info["Jan-22"] + park_info["Feb-22"]  + park_info["Mar-22"] + park_info["Apr-22"] + park_info["May-22"] + park_info["Jun-22"] + park_info["Jul-22"] + park_info["Aug-22"] + park_info["Sep-22"] + park_info["Oct-22"] + park_info["Nov-22"] + park_info["Dec-22"]
park_info
# Out:
#                                Park   Jan-22   Feb-22   Mar-22    Apr-22  \
# 0    Abraham Lincoln Birthplace NHP   5833.0  10174.0  16447.0   25848.0
# 1                         Acadia NP  10411.0  13045.0  22476.0  105126.0
# 2                         Adams NHP     84.0    125.0    204.0     262.0
# 3          African Burial Ground NM    458.0   1163.0   1667.0    2625.0
# 4              Agate Fossil Beds NM    113.0    117.0    400.0     764.0
# ..                              ...      ...      ...      ...       ...
# 382                      Wupatki NM      0.0      0.0      0.0       0.0
# 383                  Yellowstone NP      0.0      0.0      0.0       0.0
# 384                     Yosemite NP      0.0      0.0      0.0       0.0
# 385      Yukon-Charley Rivers NPRES      0.0      0.0      0.0       0.0
# 386                         Zion NP      0.0      0.0      0.0       0.0
#
#        May-22    Jun-22    Jul-22    Aug-22  Sep-22  Oct-22  Nov-22  Dec-22  \
# ...
