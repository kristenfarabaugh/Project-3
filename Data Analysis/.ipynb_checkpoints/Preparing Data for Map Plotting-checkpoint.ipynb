# %%
#Import dependences
import pandas as pd
import numpy as np
import re
import json

# %%
#Read last year's monthly visitor data into a Pandas DataFrame

jan_2022_df = pd.read_csv('../Resources/Monthly Visitors By Park/Jan Visitors By Park.csv')
jan_2022_df.dropna()
feb_2022_df = pd.read_csv('../Resources/Monthly Visitors By Park/Feb Visitors By Park.csv')
feb_2022_df.dropna()
mar_2022_df = pd.read_csv('../Resources/Monthly Visitors By Park/Mar Visitors By Park.csv')
mar_2022_df.dropna()
apr_2022_df = pd.read_csv('../Resources/Monthly Visitors By Park/Apr Visitors By Park.csv')
apr_2022_df.dropna()
may_2022_df = pd.read_csv('../Resources/Monthly Visitors By Park/May Visitors By Park.csv')
may_2022_df.dropna()
jun_2022_df = pd.read_csv('../Resources/Monthly Visitors By Park/Jun Visitors By Park.csv')
jun_2022_df.dropna()
jul_2022_df = pd.read_csv('../Resources/Monthly Visitors By Park/Jul Visitors By Park.csv')
jul_2022_df.dropna()
aug_2022_df = pd.read_csv('../Resources/Monthly Visitors By Park/Aug Visitors By Park.csv')
aug_2022_df.dropna()
sep_2022_df = pd.read_csv('../Resources/Monthly Visitors By Park/Sep Visitors By Park.csv')
sep_2022_df.dropna()
oct_2022_df = pd.read_csv('../Resources/Monthly Visitors By Park/Oct Visitors By Park.csv')
oct_2022_df.dropna()
nov_2022_df = pd.read_csv('../Resources/Monthly Visitors By Park/Nov Visitors By Park.csv')
nov_2022_df.dropna()
dec_2022_df = pd.read_csv('../Resources/Monthly Visitors By Park/Dec Visitors By Park.csv')
dec_2022_df.dropna()
# Out:
# Empty DataFrame
# Columns: [Park, Dec-22, Unnamed: 2, Unnamed: 3, Unnamed: 4, Unnamed: 5, Unnamed: 6, Unnamed: 7, Unnamed: 8, Unnamed: 9, Unnamed: 10, Unnamed: 11, Unnamed: 12, Unnamed: 13, Unnamed: 14, Unnamed: 15, Unnamed: 16, Unnamed: 17, Unnamed: 18, Unnamed: 19, Unnamed: 20]
# Index: []
#
# [0 rows x 21 columns]

# %%
#Merge all the dataframes together

monthly_visitors_2022_df = jan_2022_df.merge(feb_2022_df, on = "Park")
monthly_visitors_2022_df = monthly_visitors_2022_df.merge(mar_2022_df, on = "Park")
monthly_visitors_2022_df = monthly_visitors_2022_df.merge(apr_2022_df, on = "Park")
monthly_visitors_2022_df = monthly_visitors_2022_df.merge(may_2022_df, on = "Park")
monthly_visitors_2022_df = monthly_visitors_2022_df.merge(jun_2022_df, on = "Park")
monthly_visitors_2022_df = monthly_visitors_2022_df.merge(jul_2022_df, on = "Park")
monthly_visitors_2022_df = monthly_visitors_2022_df.merge(aug_2022_df, on = "Park")
monthly_visitors_2022_df = monthly_visitors_2022_df.merge(sep_2022_df, on = "Park")
monthly_visitors_2022_df = monthly_visitors_2022_df.merge(oct_2022_df, on = "Park")
monthly_visitors_2022_df = monthly_visitors_2022_df.merge(nov_2022_df, on = "Park")
monthly_visitors_2022_df = monthly_visitors_2022_df.merge(dec_2022_df, on = "Park")
monthly_visitors_2022_df
# Out:
#                                Park   Jan-22   Feb-22   Mar-22   Apr-22  \
# 0    Abraham Lincoln Birthplace NHP    5,833   10,174   16,447   25,848
# 1                         Acadia NP   10,411   13,045   22,476  105,126
# 2                         Adams NHP       84      125      204      262
# 3          African Burial Ground NM      458    1,163    1,667    2,625
# 4              Agate Fossil Beds NM      113      117      400      764
# ..                              ...      ...      ...      ...      ...
# 365                      Wupatki NM    7,573    8,509   26,971   17,672
# 366                  Yellowstone NP   46,615   47,300   35,593   80,283
# 367                     Yosemite NP  137,057  170,196  192,634  285,601
# 368      Yukon-Charley Rivers NPRES        2        0        0        0
# 369                         Zion NP  139,827  168,499  446,308  491,625
#
#       May-22   Jun-22   Jul-22   Aug-22   Sep-22  ... Unnamed: 11 Unnamed: 12  \
# ...

# %%
#Get rid of the unnecessary columns
monthly_visitors_2022_df = monthly_visitors_2022_df[["Park",
                                                     "Jan-22",
                                                    "Feb-22",
                                                    "Mar-22",
                                                    "Apr-22",
                                                    "May-22",
                                                     "Jun-22",
                                                     "Jul-22",
                                                     "Aug-22",
                                                     "Sep-22",
                                                    "Oct-22",
                                                    "Nov-22",
                                                    "Dec-22"]]
monthly_visitors_2022_df
# Out:
#                                Park   Jan-22   Feb-22   Mar-22   Apr-22  \
# 0    Abraham Lincoln Birthplace NHP    5,833   10,174   16,447   25,848
# 1                         Acadia NP   10,411   13,045   22,476  105,126
# 2                         Adams NHP       84      125      204      262
# 3          African Burial Ground NM      458    1,163    1,667    2,625
# 4              Agate Fossil Beds NM      113      117      400      764
# ..                              ...      ...      ...      ...      ...
# 365                      Wupatki NM    7,573    8,509   26,971   17,672
# 366                  Yellowstone NP   46,615   47,300   35,593   80,283
# 367                     Yosemite NP  137,057  170,196  192,634  285,601
# 368      Yukon-Charley Rivers NPRES        2        0        0        0
# 369                         Zion NP  139,827  168,499  446,308  491,625
#
#       May-22   Jun-22   Jul-22   Aug-22   Sep-22   Oct-22   Nov-22   Dec-22
# ...

# %%
#Convert all monthly visitor columns to numbers
monthly_visitors_2022_df["Jan-22"] = monthly_visitors_2022_df["Jan-22"].str.replace(',', '').apply(pd.to_numeric)
monthly_visitors_2022_df["Feb-22"] = monthly_visitors_2022_df["Feb-22"].str.replace(',', '').apply(pd.to_numeric)
monthly_visitors_2022_df["Mar-22"] = monthly_visitors_2022_df["Mar-22"].str.replace(',', '').apply(pd.to_numeric)
monthly_visitors_2022_df["Apr-22"] = monthly_visitors_2022_df["Apr-22"].str.replace(',', '').apply(pd.to_numeric)
monthly_visitors_2022_df["May-22"] = monthly_visitors_2022_df["May-22"].str.replace(',', '').apply(pd.to_numeric)
monthly_visitors_2022_df["Jun-22"] = monthly_visitors_2022_df["Jun-22"].str.replace(',', '').apply(pd.to_numeric)
monthly_visitors_2022_df["Jul-22"] = monthly_visitors_2022_df["Jul-22"].str.replace(',', '').apply(pd.to_numeric)
monthly_visitors_2022_df["Aug-22"] = monthly_visitors_2022_df["Aug-22"].str.replace(',', '').apply(pd.to_numeric)
monthly_visitors_2022_df["Sep-22"] = monthly_visitors_2022_df["Sep-22"].str.replace(',', '').apply(pd.to_numeric)
monthly_visitors_2022_df["Oct-22"] = monthly_visitors_2022_df["Oct-22"].str.replace(',', '').apply(pd.to_numeric)
monthly_visitors_2022_df["Nov-22"] = monthly_visitors_2022_df["Nov-22"].str.replace(',', '').apply(pd.to_numeric)
monthly_visitors_2022_df["Dec-22"] = monthly_visitors_2022_df["Dec-22"].str.replace(',', '').apply(pd.to_numeric)

monthly_visitors_2022_df
# Out:
# C:\Users\Jill Brammah\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Jill Brammah\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Jill Brammah\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# ...

# %%
#Get totalVisitors2022 column
monthly_visitors_2022_df["totalVisitors2022"] = monthly_visitors_2022_df["Jan-22"] + monthly_visitors_2022_df["Feb-22"]  + monthly_visitors_2022_df["Mar-22"] + monthly_visitors_2022_df["Apr-22"] + monthly_visitors_2022_df["May-22"] + monthly_visitors_2022_df["Jun-22"] + monthly_visitors_2022_df["Jul-22"] + monthly_visitors_2022_df["Aug-22"] + monthly_visitors_2022_df["Sep-22"] + monthly_visitors_2022_df["Oct-22"] + monthly_visitors_2022_df["Nov-22"] + monthly_visitors_2022_df["Dec-22"]
monthly_visitors_2022_df
# Out:
# C:\Users\Jill Brammah\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                Park  Jan-22  Feb-22  Mar-22  Apr-22  May-22  \
# 0    Abraham Lincoln Birthplace NHP    5833   10174   16447   25848   30360
# 1                         Acadia NP   10411   13045   22476  105126  327466
# 2                         Adams NHP      84     125     204     262    1343
# 3          African Burial Ground NM     458    1163    1667    2625    2213
# 4              Agate Fossil Beds NM     113     117     400     764    2123
# ..                              ...     ...     ...     ...     ...     ...
# ...

# %%
#Pull all park names

park_names = monthly_visitors_2022_df["Park"].unique()
park_names = park_names.tolist()
park_names
# Out:
# ['Abraham Lincoln Birthplace NHP',
#  'Acadia NP',
#  'Adams NHP',
#  'African Burial Ground NM',
#  'Agate Fossil Beds NM',
#  'Alibates Flint Quarries NM',
#  'Allegheny Portage Railroad NHS',
#  'Amistad NRA',
#  'Andersonville NHS',
#  'Andrew Johnson NHS',
#  'Antietam NB',
#  'Apostle Islands NL',
#  'Appomattox Court House NHP',
#  'Arches NP',
#  'Arkansas Post NMEM',
#  'Arlington House The R.E. Lee MEM',
#  'Assateague Island NS',
#  'Aztec Ruins NM',
#  'Badlands NP',
#  'Bandelier NM',
#  "Bent's Old Fort NHS",
#  'Bering Land Bridge NPRES',
#  'Big Bend NP',
#  'Big Cypress NPRES',
#  'Big Hole NB',
#  'Big South Fork NRRA',
#  'Big Thicket NPRES',
#  'Bighorn Canyon NRA',
#  'Biscayne NP',
#  'Black Canyon of the Gunnison NP',
#  'Blue Ridge PKWY',
#  'Booker T. Washington NM',
#  'Boston African American NHS',
#  'Boston NHP',
#  'Brown v. Board of Education NHP',
#  'Bryce Canyon NP',
#  'Buck Island Reef NM',
#  'Buffalo NR',
#  'Cabrillo NM',
#  'Camp Nelson NM',
# ...

# %%
#Use regex to get all the initials (NM, NP, etc.)

#Create an empty array for the initials
initials_list = []

pattern = '\s([A-Z\s&]+)$'

for item in park_names:
    matches = re.findall(pattern, item)
    if matches:
        initials_list.append(matches[-1])

print(initials_list)
# Out:
# ['NHP', 'NP', 'NHP', 'NM', 'NM', 'NM', 'NHS', 'NRA', 'NHS', 'NHS', 'NB', 'NL', 'NHP', 'NP', 'NMEM', 'MEM', 'NS', 'NM', 'NP', 'NM', 'NHS', 'NPRES', 'NP', 'NPRES', 'NB', 'NRRA', 'NPRES', 'NRA', 'NP', 'NP', 'PKWY', 'NM', 'NHS', 'NHP', 'NHP', 'NP', 'NM', 'NR', 'NM', 'NM', 'NS', 'NHP', 'NM', 'NP', 'NS', 'NS', 'NM', 'NS', 'NP', 'NM', 'NHS', 'NP', 'NM', 'NM', 'NM', 'NM', 'NM', 'NHP', 'NMEM', 'NP', 'NHS', 'NM', 'NRA', 'NHP', 'NMP', 'NRA', 'NM', 'NHS', 'NRES', 'NHP', 'NM', 'NP', 'NMEM', 'NB', 'NP', 'NM & PRES', 'NHP', 'NS', 'NRA', 'NP', 'NHP', 'NMEM', 'NP', 'NRA', 'NP & PRES', 'NM', 'NM', 'NP', 'MEM', 'NM', 'NHS', 'NM', 'NM', 'NHS', 'NHS', 'NP', 'NMEM', 'NS', 'NHS', 'NMEM', 'NM', 'NHS', 'NHS', 'NMEM', 'NHS', 'NB', 'NM', 'NHS', 'NHS', 'NM', 'NM & HS', 'NB', 'NHS', 'NM', 'NHS', 'NHS', 'NHS', 'NM', 'NHP', 'NM', 'NHS', 'NHS', 'NM', 'MEM', 'NHS', 'NHS', 'NMP', 'NHS', 'NP', 'NRA', 'NRA', 'NMEM', 'NHP', 'NM', 'NM', 'MEM PKWY', 'NMP', 'NM', 'NP & PRES', 'NP', 'NRA', 'NRA', 'NHP', 'NP', 'NM', 'NP', 'N
# ...

# %%
#Create a list of unique park initials
unique_initials_list = []

for item in initials_list:
    if item not in unique_initials_list:
        unique_initials_list.append(item)

unique_initials_list
# Out:
# ['NHP',
#  'NP',
#  'NM',
#  'NHS',
#  'NRA',
#  'NB',
#  'NL',
#  'NMEM',
#  'MEM',
#  'NS',
#  'NPRES',
#  'NRRA',
#  'PKWY',
#  'NR',
#  'NMP',
#  'NRES',
#  'NM & PRES',
#  'NP & PRES',
#  'NM & HS',
#  'MEM PKWY',
#  'NHP & PRES',
#  'NBP',
#  'HQ NHS',
#  'NRR',
#  'NSR',
#  'W&SR',
#  'EHP',
#  'S&RR']

# %%
unique_initials_list
# Out:
# ['NHP',
#  'NP',
#  'NM',
#  'NHS',
#  'NRA',
#  'NB',
#  'NL',
#  'NMEM',
#  'MEM',
#  'NS',
#  'NPRES',
#  'NRRA',
#  'PKWY',
#  'NR',
#  'NMP',
#  'NRES',
#  'NM & PRES',
#  'NP & PRES',
#  'NM & HS',
#  'MEM PKWY',
#  'NHP & PRES',
#  'NBP',
#  'HQ NHS',
#  'NRR',
#  'NSR',
#  'W&SR',
#  'EHP',
#  'S&RR']

# %%
#Manually create the dictionary that matches each initial to a name
initial_names_dict = {
    'NHP & Ecological Pres' : "National Historical Park and Ecological Preserve",
    'HQ NHS' : 'Headquarters National Historic Site',
    'NM & PRES': 'National Monument & Preserve',
    'NP & PRES': 'National Park & Preserve',
    'NM & HS': 'National Monument and Historic Shrine',
    'MEM PKWY': 'Memorial Parkway',
    'NHP & PRES' : 'National Park & Preserve',
    'NPRES': 'National Preserve',
    'NMEM': 'National Memorial',
    'NRRA': 'National River',
    'PKWY': 'National Parkway',
    'NRES': 'National Reserve',
    'W&SR': 'Wild & Scenic River',
    'S&RR': 'Scenic & Recreational River',
    'NHP': 'National Historical Park',
    'NMP': 'National Military Park',
    'NHS': 'National Historic Site', 
    'NRA': 'National Recreation Area',
    'MEM':'Memorial',
    'NBP': 'National Battlefield Park',
    'NRR': 'National Recreational River',
    'NSR' : 'National Scenic River',
    'EHP': 'Ecological & Historic Preserve',
    'NM': 'National Monument',
    'NB': 'National Battlefield',
    'NL': 'National Lakeshore',
    'NP': 'National Park',
    'NS': 'National Seashore',
    'NR': 'National River',
    'HS': 'Historic Shrine',
    'PRES': 'Preserve'
}

# %%
len(unique_initials_list)
# Out:
# 28

# %%
#Go through the park names and replace each initial with its corresponding name using regex
for i in range(len(park_names)):
        for initial, full_name in initial_names_dict.items():
            pattern = r'\b' + re.escape(initial) + r'(?=\s|&|$)'
            park_names[i] = re.sub(pattern, full_name, park_names[i])

park_names
# Out:
# ['Abraham Lincoln Birthplace National Historical Park',
#  'Acadia National Park',
#  'Adams National Historical Park',
#  'African Burial Ground National Monument',
#  'Agate Fossil Beds National Monument',
#  'Alibates Flint Quarries National Monument',
#  'Allegheny Portage Railroad National Historic Site',
#  'Amistad National Recreation Area',
#  'Andersonville National Historic Site',
#  'Andrew Johnson National Historic Site',
#  'Antietam National Battlefield',
#  'Apostle Islands National Lakeshore',
#  'Appomattox Court House National Historical Park',
#  'Arches National Park',
#  'Arkansas Post National Memorial',
#  'Arlington House The R.E. Lee Memorial',
#  'Assateague Island National Seashore',
#  'Aztec Ruins National Monument',
#  'Badlands National Park',
#  'Bandelier National Monument',
#  "Bent's Old Fort National Historic Site",
#  'Bering Land Bridge National Preserve',
#  'Big Bend National Park',
#  'Big Cypress National Preserve',
# ...

# %%
#Create a column with the full name
monthly_visitors_2022_df.insert(1, "Full Park Name", park_names)
monthly_visitors_2022_df
# Out:
#                                Park  \
# 0    Abraham Lincoln Birthplace NHP
# 1                         Acadia NP
# 2                         Adams NHP
# 3          African Burial Ground NM
# 4              Agate Fossil Beds NM
# ..                              ...
# 365                      Wupatki NM
# 366                  Yellowstone NP
# 367                     Yosemite NP
# 368      Yukon-Charley Rivers NPRES
# 369                         Zion NP
#
#                                         Full Park Name  Jan-22  Feb-22  \
# 0    Abraham Lincoln Birthplace National Historical...    5833   10174
# 1                                 Acadia National Park   10411   13045
# 2                       Adams National Historical Park      84     125
# 3              African Burial Ground National Monument     458    1163
# 4                  Agate Fossil Beds National Monument     113     117
# ..                                                 ...     ...     ...
# ...

# %%
#Drop the original park axis
monthly_visitors_2022_df = monthly_visitors_2022_df.drop("Park", axis =1)
monthly_visitors_2022_df
# Out:
#                                         Full Park Name  Jan-22  Feb-22  \
# 0    Abraham Lincoln Birthplace National Historical...    5833   10174
# 1                                 Acadia National Park   10411   13045
# 2                       Adams National Historical Park      84     125
# 3              African Burial Ground National Monument     458    1163
# 4                  Agate Fossil Beds National Monument     113     117
# ..                                                 ...     ...     ...
# 365                          Wupatki National Monument    7573    8509
# 366                          Yellowstone National Park   46615   47300
# 367                             Yosemite National Park  137057  170196
# 368             Yukon-Charley Rivers National Preserve       2       0
# 369                                 Zion National Park  139827  168499
#
#      Mar-22  Apr-22  May-22  Jun-22  Jul-22  Aug-22  Sep-22  Oct-22  Nov-22  \
# ...

# %%
#Rename the new column "Park"
monthly_visitors_2022_df = monthly_visitors_2022_df.rename(columns = {"Full Park Name": "Park"})
monthly_visitors_2022_df
# Out:
#                                                   Park  Jan-22  Feb-22  \
# 0    Abraham Lincoln Birthplace National Historical...    5833   10174
# 1                                 Acadia National Park   10411   13045
# 2                       Adams National Historical Park      84     125
# 3              African Burial Ground National Monument     458    1163
# 4                  Agate Fossil Beds National Monument     113     117
# ..                                                 ...     ...     ...
# 365                          Wupatki National Monument    7573    8509
# 366                          Yellowstone National Park   46615   47300
# 367                             Yosemite National Park  137057  170196
# 368             Yukon-Charley Rivers National Preserve       2       0
# 369                                 Zion National Park  139827  168499
#
#      Mar-22  Apr-22  May-22  Jun-22  Jul-22  Aug-22  Sep-22  Oct-22  Nov-22  \
# ...

# %%
# Read in all the park information

park_info_df = pd.read_csv('../Output/park_info.csv')
park_info_df
# Out:
#                                                   Name  \
# 0    Abraham Lincoln Birthplace National Historical...
# 1                                 Acadia National Park
# 2                       Adams National Historical Park
# 3                  African American Civil War Memorial
# 4              African Burial Ground National Monument
# ..                                                 ...
# 464  Yorktown Battlefield Part of Colonial National...
# 465                             Yosemite National Park
# 466                      Yucca House National Monument
# 467           Yukon - Charley Rivers National Preserve
# 468                                 Zion National Park
#
#                                   Park ID Park Code  \
# 0    77E0D7F0-1942-494A-ACE2-9004D2BDC59E      abli
# 1    6DA17C86-088E-4B4D-B862-7C1BD5CF236B      acad
# 2    E4C7784E-66A0-4D44-87D0-3E072F5FEF43      adam
# 3    1A47416F-DAA3-4137-9F30-14AF86B4E547      afam
# ...

# %%
#Rename columns for merging and for js inputting to map

park_info_df = park_info_df.rename(columns = {"Name": "Park",
                                              "Park Code": "parkCode",
                                              "Park ID": "parkID",
                                             "Entrance Fee": "entranceFee",
                                             "Entrance Fee Desc": "entranceFeeDesc"})
park_info_df
# Out:
#   File "C:\Users\Jill Brammah\AppData\Local\Temp\ipykernel_2736\207435502.py", line 6
#     "Entrance Fee": "entranceFee",
#                   ^
# SyntaxError: invalid syntax

# %%
merged_df = monthly_visitors_2022_df.merge(park_info_df, on = "Park", how = "left")
merged_df

# %%
merged_df = merged_df.dropna(subset=["Latitude"])
merged_df = merged_df.dropna(subset=["Longitude"])
merged_df

# %%
#Save the dataframe as a csv for later analysis
merged_df.to_csv("../Output/park_info_with_2022_visitor_info.csv", encoding='utf8', index=False)

# %%
#Convert the dataframe to a dictionary so it can be saved as a json file
merged_df_dict = merged_df.to_dict(orient = 'records')
print(merged_df_dict)

# %%
with open("../Output/park_info_with_2022_visitor_info.json", "w") as outfile:
    json.dump(merged_df_dict, outfile)
